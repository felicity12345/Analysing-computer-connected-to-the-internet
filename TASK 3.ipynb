# %%
import urllib.request
import requests

# CONNECTING TO EACH OF THE WEBSITES

try:
    urllib.request.urlopen('https://www.instagram.com') 
    print("Managed to contact website")

    
    urllib.request.urlopen('https://www.whatsapp.com') 
    print("Managed to contact website")

    
    urllib.request.urlopen('https://www.ebay.co.ng') 
    print("Managed to contact website")
except:
    print("Failed to contact website\n")



    
#RECONNECTING UNRESPONSIVE WEBSITE  
    
try:
    urllib.request.urlopen('https://www.ebay.co.ng')
    urllib.request.urlopen('https://www.ebay.co.ng')
    
    r = requests.get('https://www.ebay.co.ng')
    r = requests.get('https://www.ebay.co.ng')
    
    print("Response time of the website is: \n" + str(r.elapsed.total_seconds()))
    
    if (r.elapsed.total_seconds()) <1:
        print("Website is responsive")
        
    elif (r.elapsed.total_seconds())>1:
        print("website response is bad")
    
except:
    print("The website you are trying to connect is offline \n")

    
    
    
#RECONNECTING TO THE CONNECTED WEBSITE TO KNOW THEIR RESPONSE TIME OF EACH WEBSITE

try:
    urllib.request.urlopen('https://www.whatsapp.com') 
    r = requests.get('https://www.whatsapp.com')
    
    urllib.request.urlopen('https://www.instagram.com') 
    r = requests.get('https://www.instagram.com')
    
    print("Response time of the website is: \n" + str(r.elapsed.total_seconds()))
    print("Response time of the website is: \n" + str(r.elapsed.total_seconds()))
    
# USING IF STATEMENT TO PREDICT IF THE WEBSITE HAS A GOOD CONNECT OR BAD CONNECTION
    
    if (r.elapsed.total_seconds()) <=1:
        print("Website has good connection \n")
        
    elif (r.elapsed.total_seconds())>1:
        print("connection to the website is bad \n")
    
except:
    print("Website not responding")
# Out:
# Managed to contact website
# Managed to contact website
# Failed to contact website
#
# The website you are trying to connect is offline
#
# Response time of the website is:
# 0.224476
# Response time of the website is:
# 0.224476
# Website has good connection
