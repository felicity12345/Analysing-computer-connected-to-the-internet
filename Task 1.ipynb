# %%
# CREATING A MENU PROGRAM

import psutil
import platform
def menu ():
    print("[1] pick your choice of program 1")
    print("[2] pick your choice of program 2")
    print("[3] pick your choice of program 3")
    print("[4] pick your choice of program 4")
    print("[5] pick Exit")
    

menu()
pick_choice =int(input("pick a program of your choice: ")) 
while pick_choice  != 5:
    if pick_choice  == 1:
        

        
        
# Get the percentage usage of each CPU core over 10 seconds 
        core_usage = psutil.cpu_percent(10, True)
        num_core_usage = len(core_usage)
        for i in range(num_core_usage):
            print("The percentage usage for core " + str(i) +": " + str(core_usage[i]) + "% " + "number of core is " + str( num_core_usage))
 


            
# Get the amount of RAM currently being used in gigabyte     
    elif pick_choice == 2:
        mem_usage = psutil.virtual_memory()
        RAM = (mem_usage.used)/(2**30)
        print("You have " + str(RAM) + "GB of RAM")

        
        
    
# Get the name and version of the operating system  
    elif pick_choice == 3:
        version = platform.platform
        print("The name and version of the operating system is " + str(version()))
  



        
# Check whether the computer is currently busy with CPU and RAM usage over 50 percent    
    elif  pick_choice == 4:
        cpu_usage = 50
        mem_usage = 50
        cpu_usage = psutil.cpu_percent(1, False)
        mem_usage = psutil.virtual_memory().percent
        print("Your CPU and RAM usage is currently " + str(cpu_usage ) + "% " + ("and ") + str( mem_usage) + "% " + (" respectively"))
      
       
        if  cpu_usage >= 50 and mem_usage >= 50:
             print("The computer is busy")

            
        elif cpu_usage < 50 and mem_usage >= 50:
            print("Computer is not busy because only mem_usage met the condition")
            
        elif cpu_usage > 50 and mem_usage < 50:
            print("Computer is not busy because only CPU_usage met the condition")
            
        else:
            ("The computer is not busy because both CPU and RAM are less than 50%")
        
    
        
    else:
        print("You pick invalid program list")
        print("pick Valid number from the program list")
        
        
    print()
    menu()
    pick_choice =int(input("pick a program of your choice: "))
    
print("Goodbye and Goodluck")



# The inspiration for the menu list was found in the following.
# Andy Dolinski (2020) Making a menu in Python. Available at:https://www.youtube.com/watch?v=63nw00JqHo0 (Accessed 27 November 2022).
# Out:
# [1] pick your choice of program 1
# [2] pick your choice of program 2
# [3] pick your choice of program 3
# [4] pick your choice of program 4
# [5] pick Exit
